# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv("auto-mpg.csv")

# %%
df
# Out:
#       mpg  cyl   disp   hp    wt   acc  yr  origin                   car name
# 0    18.0    8  307.0  130  3504  12.0  70       1  chevrolet chevelle malibu
# 1    15.0    8  350.0  165  3693  11.5  70       1          buick skylark 320
# 2    18.0    8  318.0  150  3436  11.0  70       1         plymouth satellite
# 3    16.0    8  304.0  150  3433  12.0  70       1              amc rebel sst
# 4    17.0    8  302.0  140  3449  10.5  70       1                ford torino
# ..    ...  ...    ...  ...   ...   ...  ..     ...                        ...
# 393  27.0    4  140.0   86  2790  15.6  82       1            ford mustang gl
# 394  44.0    4   97.0   52  2130  24.6  82       2                  vw pickup
# 395  32.0    4  135.0   84  2295  11.6  82       1              dodge rampage
# 396  28.0    4  120.0   79  2625  18.6  82       1                ford ranger
# 397  31.0    4  119.0   82  2720  19.4  82       1                 chevy s-10
#
# [398 rows x 9 columns]

# %%
df.head(5)
# Out:
#     mpg  cyl   disp   hp    wt   acc  yr  origin                   car name
# 0  18.0    8  307.0  130  3504  12.0  70       1  chevrolet chevelle malibu
# 1  15.0    8  350.0  165  3693  11.5  70       1          buick skylark 320
# 2  18.0    8  318.0  150  3436  11.0  70       1         plymouth satellite
# 3  16.0    8  304.0  150  3433  12.0  70       1              amc rebel sst
# 4  17.0    8  302.0  140  3449  10.5  70       1                ford torino

# %%
df.tail(5)
# Out:
#       mpg  cyl   disp  hp    wt   acc  yr  origin         car name
# 393  27.0    4  140.0  86  2790  15.6  82       1  ford mustang gl
# 394  44.0    4   97.0  52  2130  24.6  82       2        vw pickup
# 395  32.0    4  135.0  84  2295  11.6  82       1    dodge rampage
# 396  28.0    4  120.0  79  2625  18.6  82       1      ford ranger
# 397  31.0    4  119.0  82  2720  19.4  82       1       chevy s-10

# %%
df.describe()
# Out:
#               mpg         cyl        disp           wt         acc  \
# count  398.000000  398.000000  398.000000   398.000000  398.000000
# mean    23.514573    5.454774  193.425879  2970.424623   15.568090
# std      7.815984    1.701004  104.269838   846.841774    2.757689
# min      9.000000    3.000000   68.000000  1613.000000    8.000000
# 25%     17.500000    4.000000  104.250000  2223.750000   13.825000
# 50%     23.000000    4.000000  148.500000  2803.500000   15.500000
# 75%     29.000000    8.000000  262.000000  3608.000000   17.175000
# max     46.600000    8.000000  455.000000  5140.000000   24.800000
#
#                yr      origin
# count  398.000000  398.000000
# mean    76.010050    1.572864
# std      3.697627    0.802055
# min     70.000000    1.000000
# 25%     73.000000    1.000000
# 50%     76.000000    1.000000
# 75%     79.000000    2.000000
# max     82.000000    3.000000

# %%
df.describe(include="all").T
# Out:
#           count unique         top freq         mean         std     min  \
# mpg       398.0    NaN         NaN  NaN    23.514573    7.815984     9.0
# cyl       398.0    NaN         NaN  NaN     5.454774    1.701004     3.0
# disp      398.0    NaN         NaN  NaN   193.425879  104.269838    68.0
# hp          398     94         150   22          NaN         NaN     NaN
# wt        398.0    NaN         NaN  NaN  2970.424623  846.841774  1613.0
# acc       398.0    NaN         NaN  NaN     15.56809    2.757689     8.0
# yr        398.0    NaN         NaN  NaN     76.01005    3.697627    70.0
# origin    398.0    NaN         NaN  NaN     1.572864    0.802055     1.0
# car name    398    305  ford pinto    6          NaN         NaN     NaN
#
#               25%     50%     75%     max
# mpg          17.5    23.0    29.0    46.6
# cyl           4.0     4.0     8.0     8.0
# disp       104.25   148.5   262.0   455.0
# hp            NaN     NaN     NaN     NaN
# wt        2223.75  2803.5  3608.0  5140.0
# acc        13.825    15.5  17.175    24.8
# yr           73.0    76.0    79.0    82.0
# origin        1.0     1.0     2.0     3.0
# car name      NaN     NaN     NaN     NaN

# %%
df['origin'].value_counts()
# Out:
# 1    249
# 3     79
# 2     70
# Name: origin, dtype: int64

# %%
df.isnull().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-629914d6d1c7> in <cell line: 1>()
# ----> 1 df.isnull().sum()
#
# NameError: name 'df' is not defined

# %%
df.dtypes
# Out:
# mpg         float64
# cyl           int64
# disp        float64
# hp           object
# wt            int64
# acc         float64
# yr            int64
# origin        int64
# car name     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   mpg       398 non-null    float64
#  1   cyl       398 non-null    int64
#  2   disp      398 non-null    float64
#  3   hp        398 non-null    object
#  4   wt        398 non-null    int64
#  5   acc       398 non-null    float64
#  6   yr        398 non-null    int64
#  7   origin    398 non-null    int64
#  8   car name  398 non-null    object
# dtypes: float64(3), int64(4), object(2)
# memory usage: 28.1+ KB

# %%
df.shape
# Out:
# (398, 9)

# %%
plt.hist(x=df["mpg"],color="orange")
plt.title("Auto-Mpg",fontsize=16,color='black')
plt.xlabel("mpg")
plt.ylabel("Frequency",fontsize=16,color='black')
plt.show()

# %%
df.hist(figsize=(20,20))
# Out:
# array([[<Axes: title={'center': 'mpg'}>, <Axes: title={'center': 'cyl'}>,
#         <Axes: title={'center': 'disp'}>],
#        [<Axes: title={'center': 'wt'}>, <Axes: title={'center': 'acc'}>,
#         <Axes: title={'center': 'yr'}>],
#        [<Axes: title={'center': 'origin'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
plt.boxplot(x='mpg',data=df)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f324f122710>,
#   <matplotlib.lines.Line2D at 0x7f324f120f40>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f324f01d6c0>,
#   <matplotlib.lines.Line2D at 0x7f324f01ee30>],
#  'boxes': [<matplotlib.lines.Line2D at 0x7f324f0b66b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f324f01eaa0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f324f14e2f0>],
#  'means': []}

# %%
corr=df.corr()
# Out:
# <ipython-input-21-0014364bc22a>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=df.corr()

# %%
corr
# Out:
#              mpg       cyl      disp        wt       acc        yr    origin
# mpg     1.000000 -0.775396 -0.804203 -0.831741  0.420289  0.579267  0.563450
# cyl    -0.775396  1.000000  0.950721  0.896017 -0.505419 -0.348746 -0.562543
# disp   -0.804203  0.950721  1.000000  0.932824 -0.543684 -0.370164 -0.609409
# wt     -0.831741  0.896017  0.932824  1.000000 -0.417457 -0.306564 -0.581024
# acc     0.420289 -0.505419 -0.543684 -0.417457  1.000000  0.288137  0.205873
# yr      0.579267 -0.348746 -0.370164 -0.306564  0.288137  1.000000  0.180662
# origin  0.563450 -0.562543 -0.609409 -0.581024  0.205873  0.180662  1.000000

# %%
df.plot.scatter(x="mpg",y="acc")
# Out:
# <Axes: xlabel='mpg', ylabel='acc'>

# %%
sns.heatmap(corr,annot =True,cmap="YlGnBu")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-2202ac8b3666> in <cell line: 1>()
# ----> 1 sns.heatmap(corr,annot =True,cmap="YlGnBu")
#
# TypeError: 'numpy.float64' object is not callable
